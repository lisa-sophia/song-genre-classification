# %%
import pandas as pd
import numpy as np
import string
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from operator import index
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector
from nltk import word_tokenize, pos_tag
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r'../data/GTZAN/lyrics_dataframe.csv')
df
# Out:
#             filename           artist                                 title  \
# 0    blues.00000.wav  John Lee Hooker  One Bourbon, One Scotch And One Beer
# 1    blues.00001.wav  John Lee Hooker              I'm In The Mood For Love
# 2    blues.00002.wav  John Lee Hooker             Think Twice Before You Go
# 3    blues.00003.wav  John Lee Hooker              I'm Bad Like Jesse James
# 4    blues.00004.wav  John Lee Hooker                    Walkin’ The Boogie
# ..               ...              ...                                   ...
# 970   rock.00095.wav  The Stone Roses                       Bye Bye Bad Man
# 971   rock.00096.wav  The Stone Roses       (Song For My) Sugar Spun Sister
# 972   rock.00097.wav  The Stone Roses                         Made Of Stone
# 973   rock.00098.wav  The Stone Roses                        Shoot You Down
# 974   rock.00099.wav  The Stone Roses                       This Is The One
#
#      genre                                             lyrics  instrumental
# 0    blues  One bourbon, one scotch and one beer\nOne bour...         False
# 1    blues  I'm in the mood baby, I'm in the mood for love...         False
# 2    blues  \nThink twice before you go, baby, this will b...         False
# 3    blues  \n...A little thing I'm going to do called "I'...         False
# 4    blues  Well my mama she didn't 'low me, just to stay ...         False
# ..     ...                                                ...           ...
# 970   rock  \nSoak me to my skin\nWill you drown me in you...         False
# 971   rock  \nHer hair, soft drifted snow\nDeath white, I'...         False
# 972   rock  \nYour knuckles whiten on the wheel\nThe last ...         False
# 973   rock  You know it\nYou show it\nAnd the time has com...         False
# 974   rock  A girl consumed by fire…\nWe all know her desi...         False
#
# [975 rows x 6 columns]

# %%
print(set(df.genre))
# Out:
# {'blues', 'rock', 'reggae', 'jazz', 'disco', 'pop', 'metal', 'classical', 'country', 'hiphop'}

# %%
# value counts of all data samples that have lyrics
df[df.lyrics.notnull()].genre.value_counts()
# Out:
# pop          100
# rock         100
# disco         99
# hiphop        98
# country       96
# metal         96
# reggae        96
# blues         78
# jazz          18
# classical      8
# Name: genre, dtype: int64

# %% [markdown]
# ## Filter datafame

# %% [markdown]
# - Remove instrumental songs (that do not have lyrics)
# - Decided to remove e.g. the classical genre (only 8 non-instrumental songs)

# %%
df = df[df.lyrics.notnull()]
df = df[(df.genre != "classical") & (df.genre != "jazz")]
df
# Out:
#             filename           artist                                 title  \
# 0    blues.00000.wav  John Lee Hooker  One Bourbon, One Scotch And One Beer
# 1    blues.00001.wav  John Lee Hooker              I'm In The Mood For Love
# 2    blues.00002.wav  John Lee Hooker             Think Twice Before You Go
# 3    blues.00003.wav  John Lee Hooker              I'm Bad Like Jesse James
# 4    blues.00004.wav  John Lee Hooker                    Walkin’ The Boogie
# ..               ...              ...                                   ...
# 970   rock.00095.wav  The Stone Roses                       Bye Bye Bad Man
# 971   rock.00096.wav  The Stone Roses       (Song For My) Sugar Spun Sister
# 972   rock.00097.wav  The Stone Roses                         Made Of Stone
# 973   rock.00098.wav  The Stone Roses                        Shoot You Down
# 974   rock.00099.wav  The Stone Roses                       This Is The One
#
#      genre                                             lyrics  instrumental
# 0    blues  One bourbon, one scotch and one beer\nOne bour...         False
# 1    blues  I'm in the mood baby, I'm in the mood for love...         False
# 2    blues  \nThink twice before you go, baby, this will b...         False
# 3    blues  \n...A little thing I'm going to do called "I'...         False
# 4    blues  Well my mama she didn't 'low me, just to stay ...         False
# ..     ...                                                ...           ...
# 970   rock  \nSoak me to my skin\nWill you drown me in you...         False
# 971   rock  \nHer hair, soft drifted snow\nDeath white, I'...         False
# 972   rock  \nYour knuckles whiten on the wheel\nThe last ...         False
# 973   rock  You know it\nYou show it\nAnd the time has com...         False
# 974   rock  A girl consumed by fire…\nWe all know her desi...         False
#
# [763 rows x 6 columns]

# %%
df.genre.value_counts()
# Out:
# pop        100
# rock       100
# disco       99
# hiphop      98
# country     96
# metal       96
# reggae      96
# blues       78
# Name: genre, dtype: int64

# %% [markdown]
# ### Check if any songs are not English

# %%
nlp = spacy.load('en_core_web_sm')

def get_lang_detector(nlp, name):
    return LanguageDetector()

Language.factory('language_detector', func=get_lang_detector)
nlp.add_pipe('language_detector', last=True)

# %%
indices = []
language = []
for i in range(len(df['lyrics'])):
    doc = nlp(df.iloc[i].lyrics)
    detected_language = doc._.language
    if not detected_language['language'] == 'en':
        indices.append(i)
        language.append(detected_language)
    if detected_language['language'] == 'en' and detected_language['score'] < 0.6:
        indices.append(i)
        language.append(detected_language)
        
print(indices)
# Out:
# [223, 224, 236, 662, 753]

# %%
# song "The lion sleeps tonight" was detected as Dutch -> delete
df = df.drop(df[df.title == "The Lion Sleeps Tonight"].index)

# %%
df
# Out:
#             filename           artist                                 title  \
# 0    blues.00000.wav  John Lee Hooker  One Bourbon, One Scotch And One Beer
# 1    blues.00001.wav  John Lee Hooker              I'm In The Mood For Love
# 2    blues.00002.wav  John Lee Hooker             Think Twice Before You Go
# 3    blues.00003.wav  John Lee Hooker              I'm Bad Like Jesse James
# 4    blues.00004.wav  John Lee Hooker                    Walkin’ The Boogie
# ..               ...              ...                                   ...
# 970   rock.00095.wav  The Stone Roses                       Bye Bye Bad Man
# 971   rock.00096.wav  The Stone Roses       (Song For My) Sugar Spun Sister
# 972   rock.00097.wav  The Stone Roses                         Made Of Stone
# 973   rock.00098.wav  The Stone Roses                        Shoot You Down
# 974   rock.00099.wav  The Stone Roses                       This Is The One
#
#      genre                                             lyrics  instrumental
# 0    blues  One bourbon, one scotch and one beer\nOne bour...         False
# 1    blues  I'm in the mood baby, I'm in the mood for love...         False
# 2    blues  \nThink twice before you go, baby, this will b...         False
# 3    blues  \n...A little thing I'm going to do called "I'...         False
# 4    blues  Well my mama she didn't 'low me, just to stay ...         False
# ..     ...                                                ...           ...
# 970   rock  \nSoak me to my skin\nWill you drown me in you...         False
# 971   rock  \nHer hair, soft drifted snow\nDeath white, I'...         False
# 972   rock  \nYour knuckles whiten on the wheel\nThe last ...         False
# 973   rock  You know it\nYou show it\nAnd the time has com...         False
# 974   rock  A girl consumed by fire…\nWe all know her desi...         False
#
# [762 rows x 6 columns]

# %% [markdown]
# ## Save final dataframe

# %%
df.to_csv('../data/GTZAN/filtered_df.csv', index=False)

# %%
sns.set(font_scale=1.1)
df['genre'].value_counts().plot(kind='bar', rot=0, figsize=(8,5))
plt.xlabel("Genre")
plt.ylabel("Count of songs")
plt.title(f"Counts of songs by genre. Total songs: {len(df)}", y=1.05)
plt.show()

# %%
lyrics_lengths = df['lyrics'].str.split().str.len()

print("Minimum lyrics length: " + str(min(lyrics_lengths)) + " words")
print("Maximum lyrics length: " + str(max(lyrics_lengths)) + " words")
print("Average lyrics length: " + str(np.mean(lyrics_lengths)) + " words")
print("Median:                " + str(np.median(lyrics_lengths)) + " words")
# Out:
# Minimum lyrics length: 15 words
# Maximum lyrics length: 1111 words
# Average lyrics length: 289.2795275590551 words
# Median:                243.0 words

# %%
plt.figure(figsize=(9,6))
plt.style.use('seaborn')
plt.hist(lyrics_lengths, bins=50)
plt.title("Histogram of lyrics lengths in nr. of words")
plt.show()

# %% [markdown]
# ## Cleanup and tokenize the data

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/lisa/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/lisa/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /home/lisa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# tag map for POS tag (needed for lemmatization)
tag_map = defaultdict(lambda : wordnet.NOUN)
tag_map['J'] = wordnet.ADJ
tag_map['V'] = wordnet.VERB
tag_map['R'] = wordnet.ADV

def preprocess(text, lemmatize=False):
    
    # transform to lower-case and remove punctuation
    text_p = "".join([char for char in text.lower() if char not in string.punctuation])

    # split tokens
    words = word_tokenize(text_p)
    
    # remove common english stopwords
    stop_words = stopwords.words('english')
    filtered_words = [word for word in words if word not in stop_words]

    if lemmatize:
        # lemmatization (convert each token to its base form)
        lemmatizer = WordNetLemmatizer()
        lemmatized = []
        for token, tag in pos_tag(filtered_words):
            lemma = lemmatizer.lemmatize(token, tag_map[tag[0]])
            lemmatized.append(lemma)
        return lemmatized
    
    return filtered_words

# %%
print(preprocess("Testing the pre-processing function!"))
print(preprocess("Testing the pre-processing function!", lemmatize=True))
# Out:
# ['testing', 'preprocessing', 'function']
# ['test', 'preprocessing', 'function']

# %%
tokenized = []
lemmatized = []
for post in df['lyrics']:
    tokenized.append(preprocess(post))
    lemmatized.append(preprocess(post, lemmatize=True))

# %%
print(df['lyrics'][0])
print(tokenized[0])
# Out:
# One bourbon, one scotch and one beer
# One bourbon, one scotch and one beer
#
# I said hey mister bartender, come here
# I want another drink and I want it now
# My girl, she gone, she been gone two night
# I ain't seen the girl since night before last
# Wanna get drunk, get her off my mind
# One bourbon, one scotch, one beer
# And then I sit there, drinkin, gettin' stoned, yeah yeah
# After a while, I looked down the bar, at the bartender
# I said Hey!  "Whadda ya want?"
# One bourbon, one scotch, one beer
# Well that girl, she gone, gone two night
# I haven't seen the girl since night before last
# I wanna get drunk, get her off of my mind
# One bourbon, one scotch, one beer
#
# And I sat there, gettin stoned, mellow
# Feelin so good, so good
# I looked down the bar, at the bartender
# I said hey hey!  "Whadda ya want?"
# One bourbon, one scotch, one beer
#
# Well that girl, she gone, she gone two night
# I haven't seen the girl since night before last
# I wanna get drunk, get her off of my mind
# One bourbon, one scotch, one beer
#
# Then I sit there, drinkin
# After a while, I lose my head
# I looked on the wall, at the clock on the wall
# By that time, it was quarter to two
# Last call for alcohol
# I looked down the bar, at the bartender
# I said "Hey, whadda ya want?"
# One bourbon, one scotch and one beer
#
# Songwriter:  Rudy Toombs
# ['one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'said', 'hey', 'mister', 'bartender', 'come', 'want', 'another', 'drink', 'want', 'girl', 'gone', 'gone', 'two', 'night', 'aint', 'seen', 'girl', 'since', 'night', 'last', 'wan', 'na', 'get', 'drunk', 'get', 'mind', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'sit', 'drinkin', 'gettin', 'stoned', 'yeah', 'yeah', 'looked', 'bar', 'bartender', 'said', 'hey', 'whadda', 'ya', 'want', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'well', 'girl', 'gone', 'gone', 'two', 'night', 'havent', 'seen', 'girl', 'since', 'night', 'last', 'wan', 'na', 'get', 'drunk', 'get', 'mind', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'sat', 'gettin', 'stoned', 'mellow', 'feelin', 'good', 'good', 'looked', 'bar', 'bartender', 'said', 'hey', 'hey', 'whadda', 'ya', 'want', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'well', 'girl', 'gone', 'gone', 'two', 'night', 'havent', 'seen', 'girl', 'since', 'night', 'last', 'wan', 'na', 'get', 'drunk', 'get', 'mind', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'sit', 'drinkin', 'lose', 'head', 'looked', 'wall', 'clock', 'wall', 'time', 'quarter', 'two', 'last', 'call', 'alcohol', 'looked', 'bar', 'bartender', 'said', 'hey', 'whadda', 'ya', 'want', 'one', 'bourbon', 'one', 'scotch', 'one', 'beer', 'songwriter', 'rudy', 'toombs']

# %%
df['tokenized'] = tokenized
df['lemmatized'] = lemmatized
df
# Out:
#             filename           artist                                 title  \
# 0    blues.00000.wav  John Lee Hooker  One Bourbon, One Scotch And One Beer
# 1    blues.00001.wav  John Lee Hooker              I'm In The Mood For Love
# 2    blues.00002.wav  John Lee Hooker             Think Twice Before You Go
# 3    blues.00003.wav  John Lee Hooker              I'm Bad Like Jesse James
# 4    blues.00004.wav  John Lee Hooker                    Walkin’ The Boogie
# ..               ...              ...                                   ...
# 970   rock.00095.wav  The Stone Roses                       Bye Bye Bad Man
# 971   rock.00096.wav  The Stone Roses       (Song For My) Sugar Spun Sister
# 972   rock.00097.wav  The Stone Roses                         Made Of Stone
# 973   rock.00098.wav  The Stone Roses                        Shoot You Down
# 974   rock.00099.wav  The Stone Roses                       This Is The One
#
#      genre                                             lyrics  instrumental  \
# 0    blues  One bourbon, one scotch and one beer\nOne bour...         False
# 1    blues  I'm in the mood baby, I'm in the mood for love...         False
# 2    blues  \nThink twice before you go, baby, this will b...         False
# 3    blues  \n...A little thing I'm going to do called "I'...         False
# 4    blues  Well my mama she didn't 'low me, just to stay ...         False
# ..     ...                                                ...           ...
# 970   rock  \nSoak me to my skin\nWill you drown me in you...         False
# 971   rock  \nHer hair, soft drifted snow\nDeath white, I'...         False
# 972   rock  \nYour knuckles whiten on the wheel\nThe last ...         False
# 973   rock  You know it\nYou show it\nAnd the time has com...         False
# 974   rock  A girl consumed by fire…\nWe all know her desi...         False
#
#                                              tokenized  \
# 0    [one, bourbon, one, scotch, one, beer, one, bo...
# 1    [im, mood, baby, im, mood, love, im, mood, bab...
# 2    [think, twice, go, baby, end, think, twice, go...
# 3    [little, thing, im, going, called, im, bad, li...
# 4    [well, mama, didnt, low, stay, night, long, oh...
# ..                                                 ...
# 970  [soak, skin, drown, sea, submission, ends, beg...
# 971  [hair, soft, drifted, snow, death, white, id, ...
# 972  [knuckles, whiten, wheel, last, thing, hands, ...
# 973  [know, show, time, come, shoot, sound, day, do...
# 974  [girl, consumed, fire…, know, desire, plans, m...
#
#                                             lemmatized
# 0    [one, bourbon, one, scotch, one, beer, one, bo...
# 1    [im, mood, baby, im, mood, love, im, mood, bab...
# 2    [think, twice, go, baby, end, think, twice, go...
# 3    [little, thing, im, go, call, im, bad, like, j...
# 4    [well, mama, didnt, low, stay, night, long, oh...
# ..                                                 ...
# 970  [soak, skin, drown, sea, submission, end, begi...
# 971  [hair, soft, drift, snow, death, white, id, li...
# 972  [knuckle, whiten, wheel, last, thing, hand, fe...
# 973  [know, show, time, come, shoot, sound, day, do...
# 974  [girl, consume, fire…, know, desire, plan, mak...
#
# [762 rows x 8 columns]

# %%
df.to_csv('../data/GTZAN/tokenized_df.csv', index=False)

# %% [markdown]
# ## Train test split

# %%
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['genre'], random_state=0)
df_train
# Out:
#               filename                    artist  \
# 229  country.00041.wav               Johnny Cash
# 813   reggae.00038.wav             Burning Spear
# 358    disco.00070.wav  KC and The Sunshine Band
# 863   reggae.00088.wav          Marcia Griffiths
# 692      pop.00017.wav            Britney Spears
# ..                 ...                       ...
# 268  country.00080.wav             Willie Nelson
# 950     rock.00075.wav                Simply Red
# 318    disco.00030.wav       The Gibson Brothers
# 390   hiphop.00002.wav                De La Soul
# 381    disco.00093.wav                 Van McCoy
#
#                              title    genre  \
# 229              Goin' By The Book  country
# 813              Investigation Dub   reggae
# 358     That's The Way (I Like It)    disco
# 863                Electric Boogie   reggae
# 692  (I Can't Get No) Satisfaction      pop
# ..                             ...      ...
# 268  Nothing I Can Do About It Now  country
# 950               She's Got It Bad     rock
# 318                  Latin America    disco
# 390                          Buddy   hiphop
# 381                     The Hustle    disco
#
#                                                 lyrics  instrumental  \
# 229  \nYou can see it in the movies and the paper a...         False
# 813  I and I old I know\nI and I old I say\nI and I...         False
# 358  That's the way, aha, aha\nI like it, aha, aha\...         False
# 863  \nIt's electric!\n\n\nYou can't see it\nIt's e...         False
# 692  \nI can't get no satisfaction\nI can't get no ...         False
# ..                                                 ...           ...
# 268  \nI've got a long list of real good reasons\nF...         False
# 950  \nI get off my things\nI lay down in the sidel...         False
# 318  I dream of girls I used to know\nI see the fac...         False
# 390  \nHello\nMeany, meany, meany, meany \nMeany, m...         False
# 381  Do it!\nDo it!\nDo it!\n\nDo the Hustle!\nDo t...         False
#
#                                              tokenized  \
# 229  [see, movies, paper, tv, news, somebodys, army...
# 813  [old, know, old, say, reconsider, see, upfully...
# 358  [thats, way, aha, aha, like, aha, aha, thats, ...
# 863  [electric, cant, see, electric, got, ta, feel,...
# 692  [cant, get, satisfaction, cant, get, satisfact...
# ..                                                 ...
# 268  [ive, got, long, list, real, good, reasons, th...
# 950  [get, things, lay, sidelines, dont, feel, hide...
# 318  [dream, girls, used, know, see, faces, goodhea...
# 390  [hello, meany, meany, meany, meany, meany, mea...
# 381  [hustle, hustle, hustle, hustle, hustle, hustl...
#
#                                             lemmatized
# 229  [see, movie, paper, tv, news, somebody, army, ...
# 813  [old, know, old, say, reconsider, see, upfully...
# 358  [thats, way, aha, aha, like, aha, aha, thats, ...
# 863  [electric, cant, see, electric, get, ta, feel,...
# 692  [cant, get, satisfaction, cant, get, satisfact...
# ..                                                 ...
# 268  [ive, get, long, list, real, good, reason, thi...
# 950  [get, thing, lay, sideline, dont, feel, hide, ...
# 318  [dream, girl, use, know, see, face, goodhearte...
# 390  [hello, meany, meany, meany, meany, meany, mea...
# 381  [hustle, hustle, hustle, hustle, hustle, hustl...
#
# [609 rows x 8 columns]

# %%
print(df_train.genre.value_counts())
print("")
print(df_test.genre.value_counts())
# Out:
# pop        80
# disco      79
# rock       79
# hiphop     78
# country    77
# reggae     77
# metal      77
# blues      62
# Name: genre, dtype: int64
#
# disco      20
# pop        20
# rock       20
# hiphop     20
# metal      19
# country    19
# reggae     19
# blues      16
# Name: genre, dtype: int64

# %%
df_train.to_csv('../data/train_data.csv', index=False)
df_test.to_csv('../data/test_data.csv', index=False)
